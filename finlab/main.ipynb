# %%
from fin import *
# Out:
# /home/ouvic/Eco_Web/finlab/fin/fin.env

# %%
from finlab import data, login
# from token_data import token
# token = "y90Rux5imaC1eUO6RPtxpsUZ7DtJLxnD12xhfwrXYrFUz0OmMNt9qnXUSlDHcvff#free"
import os
print(os.getenv('FIN_TOKEN'))
# token = str(os.getenv('FINLAB_TOKEN'))
# print(token)
# login(token)

# rev = data.get('monthly_revenue:當月營收')
# rev
# Out:
# test

# %%
rev_ma = rev.average(2)
rev_ma
# Out:
# symbol      000116  000930  000960  0009A0        1101       1102      1103  \
# date
# 2005-02-10     NaN     NaN     NaN     NaN   2746766.0  1094966.0  271258.0
# 2005-03-10     NaN     NaN     NaN     NaN   2156429.0   879399.5  214110.0
# 2005-04-11     NaN     NaN     NaN     NaN   2035374.5   816052.0  195916.0
# 2005-05-10     NaN     NaN     NaN     NaN   2461522.5   922459.0  234911.0
# 2005-06-10     NaN     NaN     NaN     NaN   2406308.5   905659.5  228043.0
# ...            ...     ...     ...     ...         ...        ...       ...
# 2024-05-10     NaN     NaN     NaN     NaN  12637822.5  6047943.0  246514.0
# 2024-06-11     NaN     NaN     NaN     NaN  12743384.5  6073138.0  240987.0
# 2024-07-10     NaN     NaN     NaN     NaN  13759909.5  6649083.5  250080.5
# 2024-08-12     NaN     NaN     NaN     NaN  14044615.0  6780507.5  257355.5
# 2024-09-10     NaN     NaN     NaN     NaN  13717061.0  6728286.5  262885.5
#
# ...

# %%
rev_ma_max = rev_ma.rolling(12, min_periods=6).max()
print(rev_ma_max)
# Out:
#             000116  000930  000960  0009A0        1101       1102      1103  \
# date
# 2005-02-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-03-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-04-11     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-05-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-06-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# ...            ...     ...     ...     ...         ...        ...       ...
# 2024-07-10     NaN     NaN     NaN     NaN  13759909.5  6810992.5  271932.0
# 2024-08-12     NaN     NaN     NaN     NaN  14044615.0  6810992.5  269353.5
# 2024-09-10     NaN     NaN     NaN     NaN  14044615.0  6810992.5  269353.5
# 2024-10-11     NaN     NaN     NaN     NaN  14044615.0  6810992.5  269353.5
# 2024-11-11     NaN     NaN     NaN     NaN  14798658.0  6810992.5  269353.5
#
# ...

# %%
cond1 = rev_ma == rev_ma_max
cond1
# Out:
# symbol      000116  000930  000960  0009A0   1101   1102   1103   1104   1107  \
# date
# 2005-02-10   False   False   False   False  False  False  False  False  False
# 2005-03-10   False   False   False   False  False  False  False  False  False
# 2005-04-11   False   False   False   False  False  False  False  False  False
# 2005-05-10   False   False   False   False  False  False  False  False  False
# 2005-06-10   False   False   False   False  False  False  False  False  False
# ...            ...     ...     ...     ...    ...    ...    ...    ...    ...
# 2024-05-10   False   False   False   False   True  False  False  False  False
# 2024-06-11   False   False   False   False   True  False  False  False  False
# 2024-07-10   False   False   False   False   True  False  False  False  False
# 2024-08-12   False   False   False   False   True  False  False  False  False
# 2024-09-10   False   False   False   False  False  False  False  False  False
#
# ...

# %%
from fin import *
net_revenue = get_data(dataname="monthly:net_revenue")
net_revenue_2ma = net_revenue.rolling(2).mean()
net_revenue_2ma_max = net_revenue_2ma.rolling(12, min_periods=6).max()
net_revenue_2ma == net_revenue_2ma_max
# Out:
# /home/ouvic/Eco_Web/finlab/fin/api_client/api_connector.py:267: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   monthly_revenue = pd.DataFrame(res['data'], index=res['time']).replace('', np.nan)
#             000116  000930  000960  0009A0   1101   1102   1103   1104   1107  \
# date
# 2005-02-10   False   False   False   False  False  False  False  False  False
# 2005-03-10   False   False   False   False  False  False  False  False  False
# 2005-04-11   False   False   False   False  False  False  False  False  False
# 2005-05-10   False   False   False   False  False  False  False  False  False
# 2005-06-10   False   False   False   False  False  False  False  False  False
# ...            ...     ...     ...     ...    ...    ...    ...    ...    ...
# ...

# %%
from fin import *
rev_ma = sma(dataname="monthly:net_revenue", periods=2)
rev_ma
# Out:
#             000116  000930  000960  0009A0        1101       1102      1103  \
# date
# 2005-02-10     NaN     NaN     NaN     NaN   2746766.0  1094966.0  271258.0
# 2005-03-10     NaN     NaN     NaN     NaN   2156429.0   879399.5  214110.0
# 2005-04-11     NaN     NaN     NaN     NaN   2035374.5   816052.0  195916.0
# 2005-05-10     NaN     NaN     NaN     NaN   2461522.5   922459.0  234911.0
# 2005-06-10     NaN     NaN     NaN     NaN   2406308.5   905659.5  228043.0
# ...            ...     ...     ...     ...         ...        ...       ...
# 2024-07-10     NaN     NaN     NaN     NaN  13759909.5  6649083.5  250080.5
# 2024-08-12     NaN     NaN     NaN     NaN  14044615.0  6780507.5  257355.5
# 2024-09-10     NaN     NaN     NaN     NaN  13717061.0  6728286.5  262885.5
# 2024-10-11     NaN     NaN     NaN     NaN  13164842.0  6615345.0  258676.0
# 2024-11-11     NaN     NaN     NaN     NaN  14798658.0  6534717.0  239186.5
#
# ...

# %%
rev_ma_max = rev_ma.maximum(12, min_periods=6)
rev_ma_max
# Out:
#             000116  000930  000960  0009A0        1101       1102      1103  \
# date
# 2005-02-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-03-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-04-11     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-05-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# 2005-06-10     NaN     NaN     NaN     NaN         NaN        NaN       NaN
# ...            ...     ...     ...     ...         ...        ...       ...
# 2024-07-10     NaN     NaN     NaN     NaN  13759909.5  6810992.5  271932.0
# 2024-08-12     NaN     NaN     NaN     NaN  14044615.0  6810992.5  269353.5
# 2024-09-10     NaN     NaN     NaN     NaN  14044615.0  6810992.5  269353.5
# 2024-10-11     NaN     NaN     NaN     NaN  14044615.0  6810992.5  269353.5
# 2024-11-11     NaN     NaN     NaN     NaN  14798658.0  6810992.5  269353.5
#
# ...

# %%
from fin import *

# 近2月平均營收創12個月來新高
revenue_average_new_high(check_num=12, period=2)
# Out:
#             000116  000930  000960  0009A0   1101   1102   1103   1104   1107  \
# date
# 2005-02-10   False   False   False   False  False  False  False  False  False
# 2005-03-10   False   False   False   False  False  False  False  False  False
# 2005-04-11   False   False   False   False  False  False  False  False  False
# 2005-05-10   False   False   False   False  False  False  False  False  False
# 2005-06-10   False   False   False   False  False  False  False  False  False
# ...            ...     ...     ...     ...    ...    ...    ...    ...    ...
# 2024-07-10   False   False   False   False   True  False  False  False  False
# 2024-08-12   False   False   False   False   True  False  False  False  False
# 2024-09-10   False   False   False   False  False  False  False  False  False
# 2024-10-11   False   False   False   False  False  False  False  False  False
# 2024-11-11   False   False   False   False   True  False  False  False  False
#
# ...

# %%
@type_limit
def function_name(parameter_name1:parameter_name1_type,
                   parameter_name2:parameter_name2_type) -> FinlabDataFrames:
    if check_parameter_limit:
        return ValueError("warrning")
    instantiated_filter_class = filter_class()
    return instantiated_filter_class.run_algorithm(parameter_name1=parameter_name1,
                                                    parameter_name2=parameter_name2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 @type_limit
# ----> 2 def function_name(parameter_name1:parameter_name1_type,
#       3                    parameter_name2:parameter_name2_type) -> FinlabDataFrames:
#       4     if check_parameter_limit:
#       5         return ValueError("warrning")
#
# NameError: name 'parameter_name1_type' is not defined

# %%
class NewLOW(FilterDataAnalysisBase):
    '''內部變數定義初始值'''
    close = None

    def __init__(self):
        FilterDataAnalysisBase.__init__(self)

    def _get_data(self):
        '''使用data_manager抓取資料'''
        self.close = raw_data_manager.get_fin_quotes(dataname='close')

    def run_algorithm(self, periods:int):
        '''運行選股條件邏輯'''
        self._get_data()
        signal = '''選股條件邏輯'''
        return signal

# %%
@type_limit
def function_name(parameter_name1:parameter_name1_type,
                   parameter_name2:parameter_name2_type) -> FinlabDataFrames:
    if check_parameter_limit:
        return ValueError("warrning")
    return """抓data_manager提供個資料"""

# %%
@type_limit
def close_new_low(periods:int) -> FinlabDataFrames:
    if periods >= 0:
        return ValueError("warrning")
    new_low = NewLOW()
    return new_low.run_algorithm(periods=periods)
